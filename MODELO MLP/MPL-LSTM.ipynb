# %% [markdown]
# # Dense - datos 1 dia

# %% [markdown]
# Cargamos los datos:

# %%
run Datos-1dia.ipynb

# %% [markdown]
# Construimos el modelo:

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense
from sklearn.metrics import mean_absolute_error,r2_score

# %%
def subida(list):
    resultado = []
    for i in range(1,len(list)):
        if  (list)[i] > (list)[i-1]:
            resultado.append(1)
        else:
            resultado.append(0)
    return resultado

def acierto(list1,list2):
    sum = 0
    for i in range(0,len(list1)):
        if(list1[i]==list2[i]):
            sum = sum +1
    a = sum/len(test1)
    return a

# %% [markdown]
# ### Dense RELU+ADAM

# %% [markdown]
# #### EXPERIMENTO 1: Modelo con 5 capas, dividiendo las neuronas.

# %%
def build_model1(neurons, output_size, activation_fun,loss_fun,optimizer_fun):
    model = Sequential()
    model.add(Dense(neurons, input_dim = 11, activation=activation_fun))
    model.add(Dense(round(neurons/2), activation=activation_fun))
    model.add(Dense(round(neurons/3), activation=activation_fun))
    model.add(Dense(round(neurons/4), activation=activation_fun))
    model.add(Dense(1, activation=activation_fun))
    model.compile(loss=loss_fun, optimizer=optimizer_fun, metrics=['mae'])
    return model

# %% [markdown]
# Modelo 100 neuronas:

# %%
modeldense100 = build_model1(100,1,'relu','mae','adam')
modeldense100.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 100)               1200
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 33)                1683
#
#  dense_3 (Dense)             (None, 25)                850
#
#  dense_4 (Dense)             (None, 1)                 26
#
# ...
# Total params: 8,809
# Trainable params: 8,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
modeldense100.fit(trainX1, trainy1, epochs=1000)
 
# evaluamos el modelo
scoresdense100 = modeldense100.evaluate(testX1, testy1)
# Out:
# Epoch 1/1000
# 47/47 [==============================] - 1s 2ms/step - loss: 14972.5771 - mae: 14972.5771
# Epoch 2/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5752 - mae: 14972.5752
# Epoch 3/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5752 - mae: 14972.5752
# Epoch 4/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5732 - mae: 14972.5732
# Epoch 5/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5762 - mae: 14972.5762
# Epoch 6/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5752 - mae: 14972.5752
# Epoch 7/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5752 - mae: 14972.5752
# Epoch 8/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5771 - mae: 14972.5771
# Epoch 9/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5723 - mae: 14972.5723
# Epoch 10/1000
# ...

# %%
y_preddense100 = modeldense100.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense100, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense100)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense100))
print("R-cuadrado:", r2_score(testy1, y_preddense100))
print('Tasa de acierto de subida:', acierto(test1,y_preddense100))
# Out:
# Error Absoluto Medio: 37661.21701333333
# R-cuadrado: -7.564535144437098
# Tasa de acierto de subida: 0.5240641711229946

# %% [markdown]
# Modelo 64 neuronas

# %%
modeldense64 = build_model1(64,1,'relu','mae','adam')
modeldense64.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_5 (Dense)             (None, 64)                768
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dense_7 (Dense)             (None, 21)                693
#
#  dense_8 (Dense)             (None, 16)                352
#
#  dense_9 (Dense)             (None, 1)                 17
#
# ...
# Total params: 3,910
# Trainable params: 3,910
# Non-trainable params: 0
# _________________________________________________________________

# %%
modeldense64.fit(trainX1, trainy1, epochs=1000)
 
# evaluamos el modelo
scoresdense64 = modeldense64.evaluate(testX1, testy1)
# Out:
# Epoch 1/1000
# 47/47 [==============================] - 1s 2ms/step - loss: 14972.5732 - mae: 14972.5732
# Epoch 2/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5762 - mae: 14972.5762
# Epoch 3/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5771 - mae: 14972.5771
# Epoch 4/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5762 - mae: 14972.5762
# Epoch 5/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5752 - mae: 14972.5752
# Epoch 6/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5752 - mae: 14972.5752
# Epoch 7/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5723 - mae: 14972.5723
# Epoch 8/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5723 - mae: 14972.5723
# Epoch 9/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5732 - mae: 14972.5732
# Epoch 10/1000
# ...

# %%
y_preddense64 = modeldense64.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense64, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense64)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense64))
print("R-cuadrado:", r2_score(testy1, y_preddense64))
print('Tasa de acierto de subida:', acierto(test1,y_preddense64))
# Out:
# Error Absoluto Medio: 37661.21701333333
# R-cuadrado: -7.564535144437098
# Tasa de acierto de subida: 0.5240641711229946

# %% [markdown]
# Modelo 32 neuronas:

# %%
modeldense32 = build_model1(32,1,'relu','mae','adam')
modeldense32.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_10 (Dense)            (None, 32)                384
#
#  dense_11 (Dense)            (None, 16)                528
#
#  dense_12 (Dense)            (None, 11)                187
#
#  dense_13 (Dense)            (None, 8)                 96
#
#  dense_14 (Dense)            (None, 1)                 9
#
# ...
# Total params: 1,204
# Trainable params: 1,204
# Non-trainable params: 0
# _________________________________________________________________

# %%
modeldense32.fit(trainX1, trainy1, epochs=1000)
 
# evaluamos el modelo
scoresdense32 = modeldense32.evaluate(testX1, testy1)
# Out:
# Epoch 1/1000
# 47/47 [==============================] - 1s 2ms/step - loss: 14972.5732 - mae: 14972.5732
# Epoch 2/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5762 - mae: 14972.5762
# Epoch 3/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5732 - mae: 14972.5732
# Epoch 4/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5771 - mae: 14972.5771
# Epoch 5/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5752 - mae: 14972.5752
# Epoch 6/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5762 - mae: 14972.5762
# Epoch 7/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5752 - mae: 14972.5752
# Epoch 8/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5762 - mae: 14972.5762
# Epoch 9/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 14972.5762 - mae: 14972.5762
# Epoch 10/1000
# ...

# %%
y_preddense32 = modeldense32.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense32, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense32)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense32))
print("R-cuadrado:", r2_score(testy1, y_preddense32))
print('Tasa de acierto de subida:', acierto(test1,y_preddense32))
# Out:
# Error Absoluto Medio: 37661.21701333333
# R-cuadrado: -7.564535144437098
# Tasa de acierto de subida: 0.5240641711229946

# %% [markdown]
# #### EXPERIMENTO 2:  Modelo con 5 capas, mismas neuronas cada 2 capas

# %%
def build_model2(neurons, output_size, activation_fun,loss_fun,optimizer_fun):
    model = Sequential()
    model.add(Dense(neurons, input_dim = 11, activation=activation_fun))
    model.add(Dense(round(neurons), activation=activation_fun))
    model.add(Dense(round(neurons/2), activation=activation_fun))
    model.add(Dense(round(neurons/2), activation=activation_fun))
    model.add(Dense(1, activation=activation_fun))
    model.compile(loss=loss_fun, optimizer=optimizer_fun, metrics=['mae'])
    return model

# %%
modeldense100 = build_model2(100,1,'relu','mae','adam')
modeldense100.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 100)               1200
#
#  dense_16 (Dense)            (None, 100)               10100
#
#  dense_17 (Dense)            (None, 50)                5050
#
#  dense_18 (Dense)            (None, 50)                2550
#
#  dense_19 (Dense)            (None, 1)                 51
#
# ...
# Total params: 18,951
# Trainable params: 18,951
# Non-trainable params: 0
# _________________________________________________________________

# %%
modeldense100.fit(trainX1, trainy1, epochs=1000)
 
# evaluamos el modelo
scoresdense100 = modeldense100.evaluate(testX1, testy1)
# Out:
# Epoch 1/1000
# 47/47 [==============================] - 1s 2ms/step - loss: 2925.5981 - mae: 2925.5981
# Epoch 2/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 657.9316 - mae: 657.9316
# Epoch 3/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 605.7599 - mae: 605.7599
# Epoch 4/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 631.0086 - mae: 631.0086
# Epoch 5/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 513.5120 - mae: 513.5120
# Epoch 6/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 504.4176 - mae: 504.4176
# Epoch 7/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 522.6569 - mae: 522.6569
# Epoch 8/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 620.6534 - mae: 620.6534
# Epoch 9/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 698.7748 - mae: 698.7748
# Epoch 10/1000
# ...

# %%
y_preddense100 = modeldense100.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense100, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense100)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense100))
print("R-cuadrado:", r2_score(testy1, y_preddense100))
print('Tasa de acierto de subida:', acierto(test1,y_preddense100))
# Out:
# Error Absoluto Medio: 1018.1665833333333
# R-cuadrado: 0.9890271997812651
# Tasa de acierto de subida: 0.0

# %% [markdown]
# Modelo 64 neuronas

# %%
modeldense64 = build_model2(64,1,'relu','mae','adam')
modeldense64.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_20 (Dense)            (None, 64)                768
#
#  dense_21 (Dense)            (None, 64)                4160
#
#  dense_22 (Dense)            (None, 32)                2080
#
#  dense_23 (Dense)            (None, 32)                1056
#
#  dense_24 (Dense)            (None, 1)                 33
#
# ...
# Total params: 8,097
# Trainable params: 8,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
modeldense64.fit(trainX1, trainy1, epochs=1000)
 
# evaluamos el modelo
scoresdense64 = modeldense64.evaluate(testX1, testy1)
# Out:
# Epoch 1/1000
# 47/47 [==============================] - 1s 2ms/step - loss: 1701.8872 - mae: 1701.8872
# Epoch 2/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 639.4456 - mae: 639.4456
# Epoch 3/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 608.1641 - mae: 608.1641
# Epoch 4/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 629.4399 - mae: 629.4399
# Epoch 5/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 583.1342 - mae: 583.1342
# Epoch 6/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 604.6268 - mae: 604.6268
# Epoch 7/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 571.5799 - mae: 571.5799
# Epoch 8/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 650.9205 - mae: 650.9205
# Epoch 9/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 648.0128 - mae: 648.0128
# Epoch 10/1000
# ...

# %%
y_preddense64 = modeldense64.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense64, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense64)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense64))
print("R-cuadrado:", r2_score(testy1, y_preddense64))
print('Tasa de acierto de subida:', acierto(test1,y_preddense64))
# Out:
# Error Absoluto Medio: 1063.0851381249995
# R-cuadrado: 0.9884442553189424
# Tasa de acierto de subida: 0.0

# %% [markdown]
# Modelo 32 neuronas:

# %%
modeldense32 = build_model2(32,1,'relu','mae','adam')
modeldense32.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_25 (Dense)            (None, 32)                384
#
#  dense_26 (Dense)            (None, 32)                1056
#
#  dense_27 (Dense)            (None, 16)                528
#
#  dense_28 (Dense)            (None, 16)                272
#
#  dense_29 (Dense)            (None, 1)                 17
#
# ...
# Total params: 2,257
# Trainable params: 2,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
modeldense32.fit(trainX1, trainy1, epochs=1000)
 
# evaluamos el modelo
scoresdense32 = modeldense32.evaluate(testX1, testy1)
# Out:
# Epoch 1/1000
# 47/47 [==============================] - 1s 1ms/step - loss: 14972.5732 - mae: 14972.5732
# Epoch 2/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 14972.5791 - mae: 14972.5791
# Epoch 3/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 14972.5732 - mae: 14972.5732
# Epoch 4/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 14972.5752 - mae: 14972.5752
# Epoch 5/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 14972.5723 - mae: 14972.5723
# Epoch 6/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 14972.5752 - mae: 14972.5752
# Epoch 7/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 14972.5732 - mae: 14972.5732
# Epoch 8/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 14972.5771 - mae: 14972.5771
# Epoch 9/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 14972.5791 - mae: 14972.5791
# Epoch 10/1000
# ...

# %%
y_preddense32 = modeldense32.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense32, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense32)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense32))
print("R-cuadrado:", r2_score(testy1, y_preddense32))
print('Tasa de acierto de subida:', acierto(test1,y_preddense32))
# Out:
# Error Absoluto Medio: 37661.21701333333
# R-cuadrado: -7.564535144437098
# Tasa de acierto de subida: 0.5240641711229946

# %% [markdown]
# ### EXPERIMENTO 3: Modelo 10 capas

# %%
def build_model3(neurons, output_size, activation_fun,loss_fun,optimizer_fun):
    model = Sequential()
    model.add(Dense(neurons, input_dim = 11, activation=activation_fun))
    model.add(Dense(round(neurons/2), activation=activation_fun))
    model.add(Dense(round(neurons/3), activation=activation_fun))
    model.add(Dense(round(neurons/4), activation=activation_fun))
    model.add(Dense(round(neurons/5), activation=activation_fun))
    model.add(Dense(round(neurons/6), activation=activation_fun))
    model.add(Dense(round(neurons/7), activation=activation_fun))
    model.add(Dense(round(neurons/8), activation=activation_fun))
    model.add(Dense(round(neurons/9), activation=activation_fun))
    model.add(Dense(1, activation=activation_fun))
    model.compile(loss=loss_fun, optimizer=optimizer_fun, metrics=['mae'])
    return model

# %% [markdown]
# Modelo 100 neuronas:

# %%
modeldense100 = build_model3(100,1,'relu','mae','adam')
modeldense100.summary()

modeldense100.fit(trainX1, trainy1, epochs=100)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_30 (Dense)            (None, 100)               1200
#
#  dense_31 (Dense)            (None, 50)                5050
#
#  dense_32 (Dense)            (None, 33)                1683
#
#  dense_33 (Dense)            (None, 25)                850
#
#  dense_34 (Dense)            (None, 20)                520
#
#  dense_35 (Dense)            (None, 17)                357
#
#  dense_36 (Dense)            (None, 14)                252
#
#  dense_37 (Dense)            (None, 12)                180
#
#  dense_38 (Dense)            (None, 11)                143
#
#  dense_39 (Dense)            (None, 1)                 12
#
# ...
# Total params: 10,247
# Trainable params: 10,247
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# ...

# %%
y_preddense100 = modeldense100.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense100, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense100)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense100))
print("R-cuadrado:", r2_score(testy1, y_preddense100))
print('Tasa de acierto de subida:', acierto(test1,y_preddense100))
# Out:
# Error Absoluto Medio: 1014.244447708333
# R-cuadrado: 0.989509379048705
# Tasa de acierto de subida: 0.0

# %% [markdown]
# Modelo 64 neuronas:

# %%
modeldense64 = build_model3(64,1,'relu','mae','adam')
modeldense64.summary()

modeldense64.fit(trainX1, trainy1, epochs=1000)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_40 (Dense)            (None, 64)                768
#
#  dense_41 (Dense)            (None, 32)                2080
#
#  dense_42 (Dense)            (None, 21)                693
#
#  dense_43 (Dense)            (None, 16)                352
#
#  dense_44 (Dense)            (None, 13)                221
#
#  dense_45 (Dense)            (None, 11)                154
#
#  dense_46 (Dense)            (None, 9)                 108
#
#  dense_47 (Dense)            (None, 8)                 80
#
#  dense_48 (Dense)            (None, 7)                 63
#
#  dense_49 (Dense)            (None, 1)                 8
#
# ...
# Total params: 4,527
# Trainable params: 4,527
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# ...

# %%
y_preddense64 = modeldense64.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense64, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense64)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense64))
print("R-cuadrado:", r2_score(testy1, y_preddense64))
print('Tasa de acierto de subida:', acierto(test1,y_preddense64))
# Out:
# Error Absoluto Medio: 37661.21701333333
# R-cuadrado: -7.564535144437098
# Tasa de acierto de subida: 0.5240641711229946

# %% [markdown]
# Modelo 32 neuronas:

# %%
modeldense32 = build_model3(32,1,'relu','mae','adam')
modeldense32.summary()

modeldense32.fit(trainX1, trainy1, epochs=1000)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_50 (Dense)            (None, 32)                384
#
#  dense_51 (Dense)            (None, 16)                528
#
#  dense_52 (Dense)            (None, 11)                187
#
#  dense_53 (Dense)            (None, 8)                 96
#
#  dense_54 (Dense)            (None, 6)                 54
#
#  dense_55 (Dense)            (None, 5)                 35
#
#  dense_56 (Dense)            (None, 5)                 30
#
#  dense_57 (Dense)            (None, 4)                 24
#
#  dense_58 (Dense)            (None, 4)                 20
#
#  dense_59 (Dense)            (None, 1)                 5
#
# ...
# Total params: 1,363
# Trainable params: 1,363
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# ...

# %%
y_preddense32 = modeldense32.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense32, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense32)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense32))
print("R-cuadrado:", r2_score(testy1, y_preddense32))
print('Tasa de acierto de subida:', acierto(test1,y_preddense32))
# Out:
# Error Absoluto Medio: 1066.7489664583331
# R-cuadrado: 0.9881478866581049
# Tasa de acierto de subida: 0.0

# %% [markdown]
# ### Dense RELU+ADAGRAD

# %% [markdown]
# #### EXPERIMENTO 1: Modelo con 5 capas, dividiendo las neuronas.

# %% [markdown]
# Modelo 100 neuronas:

# %%
modeldense100 = build_model1(100,1,'relu','mae','adam')
modeldense100.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_60 (Dense)            (None, 100)               1200
#
#  dense_61 (Dense)            (None, 50)                5050
#
#  dense_62 (Dense)            (None, 33)                1683
#
#  dense_63 (Dense)            (None, 25)                850
#
#  dense_64 (Dense)            (None, 1)                 26
#
# ...
# Total params: 8,809
# Trainable params: 8,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
modeldense100.fit(trainX1, trainy1, epochs=1000)
 
# evaluamos el modelo
scoresdense100 = modeldense100.evaluate(testX1, testy1)
# Out:
# Epoch 1/1000
# 47/47 [==============================] - 1s 2ms/step - loss: 4830.4233 - mae: 4830.4233
# Epoch 2/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 702.9805 - mae: 702.9805
# Epoch 3/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 616.8591 - mae: 616.8591
# Epoch 4/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 556.8814 - mae: 556.8814
# Epoch 5/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 520.6407 - mae: 520.6407
# Epoch 6/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 551.4085 - mae: 551.4085
# Epoch 7/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 540.8735 - mae: 540.8735
# Epoch 8/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 531.1501 - mae: 531.1501
# Epoch 9/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 504.8209 - mae: 504.8209
# Epoch 10/1000
# ...

# %%
y_preddense100 = modeldense100.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense100, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense100)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense100))
print("R-cuadrado:", r2_score(testy1, y_preddense100))
print('Tasa de acierto de subida:', acierto(test1,y_preddense100))
# Out:
# Error Absoluto Medio: 1051.214250625
# R-cuadrado: 0.9883812348447194
# Tasa de acierto de subida: 0.0

# %% [markdown]
# Modelo 64 neuronas

# %%
modeldense64 = build_model1(64,1,'relu','mae','adam')
modeldense64.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_65 (Dense)            (None, 64)                768
#
#  dense_66 (Dense)            (None, 32)                2080
#
#  dense_67 (Dense)            (None, 21)                693
#
#  dense_68 (Dense)            (None, 16)                352
#
#  dense_69 (Dense)            (None, 1)                 17
#
# ...
# Total params: 3,910
# Trainable params: 3,910
# Non-trainable params: 0
# _________________________________________________________________

# %%
modeldense64.fit(trainX1, trainy1, epochs=1000)
 
# evaluamos el modelo
scoresdense64 = modeldense64.evaluate(testX1, testy1)
# Out:
# Epoch 1/1000
# 47/47 [==============================] - 1s 1ms/step - loss: 2537.2820 - mae: 2537.2820
# Epoch 2/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 631.6338 - mae: 631.6338
# Epoch 3/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 661.5729 - mae: 661.5729
# Epoch 4/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 671.1880 - mae: 671.1880
# Epoch 5/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 578.1689 - mae: 578.1689
# Epoch 6/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 591.6841 - mae: 591.6841
# Epoch 7/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 576.1924 - mae: 576.1924
# Epoch 8/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 594.1084 - mae: 594.1084
# Epoch 9/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 533.0210 - mae: 533.0210
# Epoch 10/1000
# ...

# %%
y_preddense64 = modeldense64.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense64, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense64)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense64))
print("R-cuadrado:", r2_score(testy1, y_preddense64))
print('Tasa de acierto de subida:', acierto(test1,y_preddense64))
# Out:
# Error Absoluto Medio: 990.4460606249996
# R-cuadrado: 0.9895347350813539
# Tasa de acierto de subida: 0.0

# %% [markdown]
# Modelo 32 neuronas:

# %%
modeldense32 = build_model1(32,1,'relu','mae','adam')
modeldense32.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_70 (Dense)            (None, 32)                384
#
#  dense_71 (Dense)            (None, 16)                528
#
#  dense_72 (Dense)            (None, 11)                187
#
#  dense_73 (Dense)            (None, 8)                 96
#
#  dense_74 (Dense)            (None, 1)                 9
#
# ...
# Total params: 1,204
# Trainable params: 1,204
# Non-trainable params: 0
# _________________________________________________________________

# %%
modeldense32.fit(trainX1, trainy1, epochs=1000)
 
# evaluamos el modelo
scoresdense32 = modeldense32.evaluate(testX1, testy1)
# Out:
# Epoch 1/1000
# 47/47 [==============================] - 1s 1ms/step - loss: 9890.2158 - mae: 9890.2158
# Epoch 2/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 1849.2274 - mae: 1849.2274
# Epoch 3/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 710.1609 - mae: 710.1609
# Epoch 4/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 703.6973 - mae: 703.6973
# Epoch 5/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 573.2355 - mae: 573.2355
# Epoch 6/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 593.6219 - mae: 593.6219
# Epoch 7/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 535.0922 - mae: 535.0922
# Epoch 8/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 538.7068 - mae: 538.7068
# Epoch 9/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 534.5298 - mae: 534.5298
# Epoch 10/1000
# ...

# %%
y_preddense32 = modeldense32.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense32, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense32)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense32))
print("R-cuadrado:", r2_score(testy1, y_preddense32))
print('Tasa de acierto de subida:', acierto(test1,y_preddense32))
# Out:
# Error Absoluto Medio: 1012.494138125
# R-cuadrado: 0.9892653044737978
# Tasa de acierto de subida: 0.0

# %% [markdown]
# #### EXPERIMENTO 2:  Modelo con 5 capas, mismas neuronas cada 2 capas

# %%
modeldense100 = build_model2(100,1,'relu','mae','adam')
modeldense100.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_75 (Dense)            (None, 100)               1200
#
#  dense_76 (Dense)            (None, 100)               10100
#
#  dense_77 (Dense)            (None, 50)                5050
#
#  dense_78 (Dense)            (None, 50)                2550
#
#  dense_79 (Dense)            (None, 1)                 51
#
# ...
# Total params: 18,951
# Trainable params: 18,951
# Non-trainable params: 0
# _________________________________________________________________

# %%
modeldense100.fit(trainX1, trainy1, epochs=1000)
 
# evaluamos el modelo
scoresdense100 = modeldense100.evaluate(testX1, testy1)
# Out:
# Epoch 1/1000
# 47/47 [==============================] - 1s 2ms/step - loss: 3893.7200 - mae: 3893.7200
# Epoch 2/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 630.3287 - mae: 630.3287
# Epoch 3/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 591.7966 - mae: 591.7966
# Epoch 4/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 569.7422 - mae: 569.7422
# Epoch 5/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 568.1124 - mae: 568.1124
# Epoch 6/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 553.7500 - mae: 553.7500
# Epoch 7/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 593.4954 - mae: 593.4954
# Epoch 8/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 537.4488 - mae: 537.4488
# Epoch 9/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 523.3575 - mae: 523.3575
# Epoch 10/1000
# ...

# %%
y_preddense100 = modeldense100.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense100, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense100)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense100))
print("R-cuadrado:", r2_score(testy1, y_preddense100))
print('Tasa de acierto de subida:', acierto(test1,y_preddense100))
# Out:
# Error Absoluto Medio: 1053.6539443749998
# R-cuadrado: 0.9887109691737379
# Tasa de acierto de subida: 0.0

# %% [markdown]
# Modelo 64 neuronas

# %%
modeldense64 = build_model2(64,1,'relu','mae','adam')
modeldense64.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_80 (Dense)            (None, 64)                768
#
#  dense_81 (Dense)            (None, 64)                4160
#
#  dense_82 (Dense)            (None, 32)                2080
#
#  dense_83 (Dense)            (None, 32)                1056
#
#  dense_84 (Dense)            (None, 1)                 33
#
# ...
# Total params: 8,097
# Trainable params: 8,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
modeldense64.fit(trainX1, trainy1, epochs=1000)
 
# evaluamos el modelo
scoresdense64 = modeldense64.evaluate(testX1, testy1)
# Out:
# Epoch 1/1000
# 47/47 [==============================] - 1s 1ms/step - loss: 3419.6838 - mae: 3419.6838
# Epoch 2/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 674.8925 - mae: 674.8925
# Epoch 3/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 583.4081 - mae: 583.4081
# Epoch 4/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 572.3318 - mae: 572.3318
# Epoch 5/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 543.6428 - mae: 543.6428
# Epoch 6/1000
# 47/47 [==============================] - 0s 3ms/step - loss: 587.5596 - mae: 587.5596
# Epoch 7/1000
# 47/47 [==============================] - 0s 3ms/step - loss: 588.3524 - mae: 588.3524
# Epoch 8/1000
# 47/47 [==============================] - 0s 3ms/step - loss: 586.4088 - mae: 586.4088
# Epoch 9/1000
# 47/47 [==============================] - 0s 2ms/step - loss: 629.2012 - mae: 629.2012
# Epoch 10/1000
# ...

# %%
y_preddense64 = modeldense64.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense64, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense64)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense64))
print("R-cuadrado:", r2_score(testy1, y_preddense64))
print('Tasa de acierto de subida:', acierto(test1,y_preddense64))
# Out:
# Error Absoluto Medio: 1073.9316362499999
# R-cuadrado: 0.9882357323339905
# Tasa de acierto de subida: 0.0

# %% [markdown]
# Modelo 32 neuronas:

# %%
modeldense32 = build_model2(32,1,'relu','mae','adam')
modeldense32.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_85 (Dense)            (None, 32)                384
#
#  dense_86 (Dense)            (None, 32)                1056
#
#  dense_87 (Dense)            (None, 16)                528
#
#  dense_88 (Dense)            (None, 16)                272
#
#  dense_89 (Dense)            (None, 1)                 17
#
# ...
# Total params: 2,257
# Trainable params: 2,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
modeldense32.fit(trainX1, trainy1, epochs=1000)
 
# evaluamos el modelo
scoresdense32 = modeldense32.evaluate(testX1, testy1)
# Out:
# Epoch 1/1000
# 47/47 [==============================] - 1s 1ms/step - loss: 4916.3838 - mae: 4916.3838
# Epoch 2/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 816.6404 - mae: 816.6404
# Epoch 3/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 680.2380 - mae: 680.2380
# Epoch 4/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 660.4116 - mae: 660.4116
# Epoch 5/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 587.8246 - mae: 587.8246
# Epoch 6/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 570.5634 - mae: 570.5634
# Epoch 7/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 563.7677 - mae: 563.7677
# Epoch 8/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 612.1019 - mae: 612.1019
# Epoch 9/1000
# 47/47 [==============================] - 0s 1ms/step - loss: 618.1902 - mae: 618.1902
# Epoch 10/1000
# ...

# %%
y_preddense32 = modeldense32.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense32, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense32)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense32))
print("R-cuadrado:", r2_score(testy1, y_preddense32))
print('Tasa de acierto de subida:', acierto(test1,y_preddense32))
# Out:
# Error Absoluto Medio: 1030.04684375
# R-cuadrado: 0.9890864533789329
# Tasa de acierto de subida: 0.0

# %% [markdown]
# ### EXPERIMENTO 3: Modelo 10 capas

# %% [markdown]
# Modelo 100 neuronas:

# %%
modeldense100 = build_model3(100,1,'relu','mae','adam')
modeldense100.summary()

modeldense100.fit(trainX1, trainy1, epochs=100)
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_90 (Dense)            (None, 100)               1200
#
#  dense_91 (Dense)            (None, 50)                5050
#
#  dense_92 (Dense)            (None, 33)                1683
#
#  dense_93 (Dense)            (None, 25)                850
#
#  dense_94 (Dense)            (None, 20)                520
#
#  dense_95 (Dense)            (None, 17)                357
#
#  dense_96 (Dense)            (None, 14)                252
#
#  dense_97 (Dense)            (None, 12)                180
#
#  dense_98 (Dense)            (None, 11)                143
#
#  dense_99 (Dense)            (None, 1)                 12
#
# ...
# Total params: 10,247
# Trainable params: 10,247
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# ...

# %%
y_preddense100 = modeldense100.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense100, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense100)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense100))
print("R-cuadrado:", r2_score(testy1, y_preddense100))
print('Tasa de acierto de subida:', acierto(test1,y_preddense100))
# Out:
# Error Absoluto Medio: 1774.6626758333337
# R-cuadrado: 0.9757993312186811
# Tasa de acierto de subida: 0.0

# %% [markdown]
# Modelo 64 neuronas:

# %%
modeldense64 = build_model3(64,1,'relu','mae','adam')
modeldense64.summary()

modeldense64.fit(trainX1, trainy1, epochs=1000)
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_100 (Dense)           (None, 64)                768
#
#  dense_101 (Dense)           (None, 32)                2080
#
#  dense_102 (Dense)           (None, 21)                693
#
#  dense_103 (Dense)           (None, 16)                352
#
#  dense_104 (Dense)           (None, 13)                221
#
#  dense_105 (Dense)           (None, 11)                154
#
#  dense_106 (Dense)           (None, 9)                 108
#
#  dense_107 (Dense)           (None, 8)                 80
#
#  dense_108 (Dense)           (None, 7)                 63
#
#  dense_109 (Dense)           (None, 1)                 8
#
# ...
# Total params: 4,527
# Trainable params: 4,527
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# ...

# %%
y_preddense64 = modeldense64.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense64, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense64)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense64))
print("R-cuadrado:", r2_score(testy1, y_preddense64))
print('Tasa de acierto de subida:', acierto(test1,y_preddense64))
# Out:
# Error Absoluto Medio: 1135.4505245833334
# R-cuadrado: 0.9876776241120538
# Tasa de acierto de subida: 0.0

# %% [markdown]
# Modelo 32 neuronas:

# %%
modeldense32 = build_model3(32,1,'relu','mae','adam')
modeldense32.summary()

modeldense32.fit(trainX1, trainy1, epochs=1000)
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_110 (Dense)           (None, 32)                384
#
#  dense_111 (Dense)           (None, 16)                528
#
#  dense_112 (Dense)           (None, 11)                187
#
#  dense_113 (Dense)           (None, 8)                 96
#
#  dense_114 (Dense)           (None, 6)                 54
#
#  dense_115 (Dense)           (None, 5)                 35
#
#  dense_116 (Dense)           (None, 5)                 30
#
#  dense_117 (Dense)           (None, 4)                 24
#
#  dense_118 (Dense)           (None, 4)                 20
#
#  dense_119 (Dense)           (None, 1)                 5
#
# ...
# Total params: 1,363
# Trainable params: 1,363
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# ...

# %%
y_preddense32 = modeldense32.predict(testX1)

# %%
plt.figure(figsize = (20,6))
plt.plot(testy1.reset_index(drop=True),label = "Valores reales")
plt.plot(y_preddense32, label = "Prediccion")
plt.legend()

# %%
test1 =subida(testy1)
pred1 = subida(y_preddense32)
print("Error Absoluto Medio:", mean_absolute_error(testy1, y_preddense32))
print("R-cuadrado:", r2_score(testy1, y_preddense32))
print('Tasa de acierto de subida:', acierto(test1,y_preddense32))
# Out:
# Error Absoluto Medio: 986.4314420833333
# R-cuadrado: 0.9897403347521816
# Tasa de acierto de subida: 0.0
