# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # INTERVALO 1

# %%
df1 = pd.DataFrame()
df1['100 Neuronas'] = None
df1['64 Neuronas'] = None
df1['32 Neuronas'] = None
df1.loc['Experimento 1- RELU+ADAM'] = [0.5226666666666666,0.5386666666666666,0.13866666666666666]
df1.loc['Experimento 2- RELU+ADAM'] = [0.0,0.07466666666666667,0.0]
df1.loc['Experimento 3- RELU+ADAM'] =[0.0,0.13866666666666666,0.33866666666666667]
df1.loc['Experimento 1- RELU+ADAGRAD'] = [0.528,0.48,0.36533333333333334]
df1.loc['Experimento 2- RELU+ADAGRAD'] = [0.128,0.16266666666666665,0.33866666666666667]
df1.loc['Experimento 3- RELU+ADAGRAD'] = [0.17333333333333334,0.17333333333333334,0.13866666666666666]
df1
# Out:
#                              100 Neuronas  64 Neuronas  32 Neuronas
# Experimento 1- RELU+ADAM         0.522667     0.538667     0.138667
# Experimento 2- RELU+ADAM         0.000000     0.074667     0.000000
# Experimento 3- RELU+ADAM         0.000000     0.138667     0.338667
# Experimento 1- RELU+ADAGRAD      0.528000     0.480000     0.365333
# Experimento 2- RELU+ADAGRAD      0.128000     0.162667     0.338667
# Experimento 3- RELU+ADAGRAD      0.173333     0.173333     0.138667

# %%
df2 = pd.DataFrame()
df2['100 Neuronas'] = None
df2['64 Neuronas'] = None
df2['32 Neuronas'] = None
df2.loc['Experimento 1- RELU+ADAM'] = [0.11813186813186813,0.5796703296703297,0.11813186813186813]
df2.loc['Experimento 2- RELU+ADAM'] = [0.0,0.1346153846153846,0.1346153846153846]
df2.loc['Experimento 3- RELU+ADAM'] = [0.17582417582417584,0.3489010989010989,0.0]
df2.loc['Experimento 1- RELU+ADAGRAD'] = [0.45604395604395603,0.29945054945054944,0.2664835164835165]
df2.loc['Experimento 2- RELU+ADAGRAD'] =[0.12637362637362637,0.1510989010989011,0.08791208791208792]
df2.loc['Experimento 3- RELU+ADAGRAD'] = [0.1620879120879121,0.17582417582417584, 0.3489010989010989]
df2
# Out:
#                              100 Neuronas  64 Neuronas  32 Neuronas
# Experimento 1- RELU+ADAM         0.118132     0.579670     0.118132
# Experimento 2- RELU+ADAM         0.000000     0.134615     0.134615
# Experimento 3- RELU+ADAM         0.175824     0.348901     0.000000
# Experimento 1- RELU+ADAGRAD      0.456044     0.299451     0.266484
# Experimento 2- RELU+ADAGRAD      0.126374     0.151099     0.087912
# Experimento 3- RELU+ADAGRAD      0.162088     0.175824     0.348901

# %%
df3 = pd.DataFrame()
df3['100 Neuronas'] = None
df3['64 Neuronas'] = None
df3['32 Neuronas'] = None
df3.loc['Experimento 1- RELU+ADAM'] = [0.5027777777777778,0.11388888888888889,0.11388888888888889]
df3.loc['Experimento 2- RELU+ADAM'] = [0.11388888888888889,0.0,0.0]
df3.loc['Experimento 3- RELU+ADAM'] = [0.1361111111111111,0.14166666666666666,0.15]
df3.loc['Experimento 1- RELU+ADAGRAD'] =[0.3861111111111111,0.11388888888888889,0.11388888888888889]
df3.loc['Experimento 2- RELU+ADAGRAD'] = [0.13333333333333333,0.08055555555555556,0.1527777777777778]
df3.loc['Experimento 3- RELU+ADAGRAD'] = [0.06388888888888888,0.11944444444444445,0.1111111111111111]
df3
# Out:
#                              100 Neuronas  64 Neuronas  32 Neuronas
# Experimento 1- RELU+ADAM         0.502778     0.113889     0.113889
# Experimento 2- RELU+ADAM         0.113889     0.000000     0.000000
# Experimento 3- RELU+ADAM         0.136111     0.141667     0.150000
# Experimento 1- RELU+ADAGRAD      0.386111     0.113889     0.113889
# Experimento 2- RELU+ADAGRAD      0.133333     0.080556     0.152778
# Experimento 3- RELU+ADAGRAD      0.063889     0.119444     0.111111

# %%
fig = plt.figure(figsize=(15,20))
fig.add_subplot(2,2,1)
plt.plot(df1.loc['Experimento 1- RELU+ADAM'],'o-',label ='Experimento 1- RELU+ADAM',color ='red')
plt.plot(df1.loc['Experimento 2- RELU+ADAM'],'o-',label ='Experimento 2- RELU+ADAM',color ='olive')
plt.plot(df1.loc['Experimento 3- RELU+ADAM'],'o-',label ='Experimento 3- RELU+ADAM',color ='cyan')
plt.plot(df1.loc['Experimento 1- RELU+ADAGRAD'],'o-',label ='Experimento 1- RELU+ADAGRAD',color ='purple')
plt.plot(df1.loc['Experimento 2- RELU+ADAGRAD'],'o-',label ='Experimento 2- RELU+ADAGRAD',color ='orange')
plt.plot(df1.loc['Experimento 3- RELU+ADAGRAD'],'o-',label ='Experimento 3- RELU+ADAGRAD',color ='yellow')
plt.title('Conjunto de datos 1')
fig.add_subplot(2,2,2)
plt.plot(df2.loc['Experimento 1- RELU+ADAM'],'o-',label ='Experimento 1- RELU+ADAM' ,color ='red')
plt.plot(df2.loc['Experimento 2- RELU+ADAM'],'o-',label ='Experimento 2- RELU+ADAM',color ='olive')
plt.plot(df2.loc['Experimento 3- RELU+ADAM'],'o-',label ='Experimento 3- RELU+ADAM',color ='cyan')
plt.plot(df2.loc['Experimento 1- RELU+ADAGRAD'],'o-',label ='Experimento 1- RELU+ADAGRAD',color ='purple')
plt.plot(df2.loc['Experimento 2- RELU+ADAGRAD'],'o-',label ='Experimento 2- RELU+ADAGRAD',color ='orange')
plt.plot(df2.loc['Experimento 3- RELU+ADAGRAD'],'o-',label ='Experimento 3- RELU+ADAGRAD',color ='yellow')
plt.title('Conjunto de datos 2')
fig.add_subplot(2,2,3)
plt.plot(df3.loc['Experimento 1- RELU+ADAM'],'o-',label ='Experimento 1- RELU+ADAM',color ='red')
plt.plot(df3.loc['Experimento 2- RELU+ADAM'],'o-',label ='Experimento 2- RELU+ADAM',color ='olive')
plt.plot(df3.loc['Experimento 3- RELU+ADAM'],'o-',label ='Experimento 3- RELU+ADAM',color ='cyan')
plt.plot(df3.loc['Experimento 1- RELU+ADAGRAD'],'o-',label ='Experimento 1- RELU+ADAGRAD',color ='purple')
plt.plot(df3.loc['Experimento 2- RELU+ADAGRAD'],'o-',label ='Experimento 2- RELU+ADAGRAD',color ='orange')
plt.plot(df3.loc['Experimento 3- RELU+ADAGRAD'],'o-',label ='Experimento 3- RELU+ADAGRAD',color ='yellow')
plt.title('Conjunto de datos 3')
plt.legend(bbox_to_anchor = (2, 1))

# %% [markdown]
# # INTERVALO 2

# %%
df1 = pd.DataFrame()
df1['100 Neuronas'] = None
df1['64 Neuronas'] = None
df1['32 Neuronas'] = None
df1.loc['Experimento 1- RELU+ADAM'] = [0.5973333333333334,0.14666666666666667,0.368]
df1.loc['Experimento 2- RELU+ADAM'] = [0.33866666666666667,0.16266666666666665,0.16266666666666665]
df1.loc['Experimento 3- RELU+ADAM'] =[0.21866666666666668,0.21866666666666668,0.0]
df1.loc['Experimento 1- RELU+ADAGRAD'] = [0.568,0.43733333333333335,0.14666666666666667]
df1.loc['Experimento 2- RELU+ADAGRAD'] = [0.0,0.10133333333333333,0.11466666666666667]
df1.loc['Experimento 3- RELU+ADAGRAD'] = [0.14666666666666667,0.058666666666666666,0.0]
df1
# Out:
#                              100 Neuronas  64 Neuronas  32 Neuronas
# Experimento 1- RELU+ADAM         0.597333     0.146667     0.368000
# Experimento 2- RELU+ADAM         0.338667     0.162667     0.162667
# Experimento 3- RELU+ADAM         0.218667     0.218667     0.000000
# Experimento 1- RELU+ADAGRAD      0.568000     0.437333     0.146667
# Experimento 2- RELU+ADAGRAD      0.000000     0.101333     0.114667
# Experimento 3- RELU+ADAGRAD      0.146667     0.058667     0.000000

# %%
df2 = pd.DataFrame()
df2['100 Neuronas'] = None
df2['64 Neuronas'] = None
df2['32 Neuronas'] = None
df2.loc['Experimento 1- RELU+ADAM'] = [0.5714285714285714,0.5879120879120879,0.5027472527472527]
df2.loc['Experimento 2- RELU+ADAM'] = [0.1620879120879121,0.03296703296703297,0.12087912087912088]
df2.loc['Experimento 3- RELU+ADAM'] = [0.32142857142857145,0.1620879120879121,0.0]
df2.loc['Experimento 1- RELU+ADAGRAD'] = [0.3983516483516483,0.12637362637362637,0.12362637362637363]
df2.loc['Experimento 2- RELU+ADAGRAD'] =[0.20604395604395603,0.22527472527472528,0.22527472527472528]
df2.loc['Experimento 3- RELU+ADAGRAD'] = [0.22527472527472528,0.1620879120879121,0.06318681318681318]
df2
# Out:
#                              100 Neuronas  64 Neuronas  32 Neuronas
# Experimento 1- RELU+ADAM         0.571429     0.587912     0.502747
# Experimento 2- RELU+ADAM         0.162088     0.032967     0.120879
# Experimento 3- RELU+ADAM         0.321429     0.162088     0.000000
# Experimento 1- RELU+ADAGRAD      0.398352     0.126374     0.123626
# Experimento 2- RELU+ADAGRAD      0.206044     0.225275     0.225275
# Experimento 3- RELU+ADAGRAD      0.225275     0.162088     0.063187

# %%
df3 = pd.DataFrame()
df3['100 Neuronas'] = None
df3['64 Neuronas'] = None
df3['32 Neuronas'] = None
df3.loc['Experimento 1- RELU+ADAM'] = [0.12222222222222222,0.125,0.12222222222222222]
df3.loc['Experimento 2- RELU+ADAM'] = [0.1638888888888889,0.35555555555555557,0.0]
df3.loc['Experimento 3- RELU+ADAM'] = [0.3527777777777778,0.019444444444444445,0.0]
df3.loc['Experimento 1- RELU+ADAGRAD'] =[0.425,0.30277777777777776,0.2638888888888889]
df3.loc['Experimento 2- RELU+ADAGRAD'] = [0.1361111111111111,0.12222222222222222,0.08333333333333333]
df3.loc['Experimento 3- RELU+ADAGRAD'] = [0.0,0.0,0.0]
df3
# Out:
#                              100 Neuronas  64 Neuronas  32 Neuronas
# Experimento 1- RELU+ADAM         0.122222     0.125000     0.122222
# Experimento 2- RELU+ADAM         0.163889     0.355556     0.000000
# Experimento 3- RELU+ADAM         0.352778     0.019444     0.000000
# Experimento 1- RELU+ADAGRAD      0.425000     0.302778     0.263889
# Experimento 2- RELU+ADAGRAD      0.136111     0.122222     0.083333
# Experimento 3- RELU+ADAGRAD      0.000000     0.000000     0.000000

# %%
fig = plt.figure(figsize=(15,20))
fig.add_subplot(2,2,1)
plt.plot(df1.loc['Experimento 1- RELU+ADAM'],'o-',label ='Experimento 1- RELU+ADAM',color ='red')
plt.plot(df1.loc['Experimento 2- RELU+ADAM'],'o-',label ='Experimento 2- RELU+ADAM',color ='olive')
plt.plot(df1.loc['Experimento 3- RELU+ADAM'],'o-',label ='Experimento 3- RELU+ADAM',color ='cyan')
plt.plot(df1.loc['Experimento 1- RELU+ADAGRAD'],'o-',label ='Experimento 1- RELU+ADAGRAD',color ='purple')
plt.plot(df1.loc['Experimento 2- RELU+ADAGRAD'],'o-',label ='Experimento 2- RELU+ADAGRAD',color ='orange')
plt.plot(df1.loc['Experimento 3- RELU+ADAGRAD'],'o-',label ='Experimento 3- RELU+ADAGRAD',color ='yellow')
plt.title('Conjunto de datos 1')
fig.add_subplot(2,2,2)
plt.plot(df2.loc['Experimento 1- RELU+ADAM'],'o-',label ='Experimento 1- RELU+ADAM' ,color ='red')
plt.plot(df2.loc['Experimento 2- RELU+ADAM'],'o-',label ='Experimento 2- RELU+ADAM',color ='olive')
plt.plot(df2.loc['Experimento 3- RELU+ADAM'],'o-',label ='Experimento 3- RELU+ADAM',color ='cyan')
plt.plot(df2.loc['Experimento 1- RELU+ADAGRAD'],'o-',label ='Experimento 1- RELU+ADAGRAD',color ='purple')
plt.plot(df2.loc['Experimento 2- RELU+ADAGRAD'],'o-',label ='Experimento 2- RELU+ADAGRAD',color ='orange')
plt.plot(df2.loc['Experimento 3- RELU+ADAGRAD'],'o-',label ='Experimento 3- RELU+ADAGRAD',color ='yellow')
plt.title('Conjunto de datos 2')
fig.add_subplot(2,2,3)
plt.plot(df3.loc['Experimento 1- RELU+ADAM'],'o-',label ='Experimento 1- RELU+ADAM',color ='red')
plt.plot(df3.loc['Experimento 2- RELU+ADAM'],'o-',label ='Experimento 2- RELU+ADAM',color ='olive')
plt.plot(df3.loc['Experimento 3- RELU+ADAM'],'o-',label ='Experimento 3- RELU+ADAM',color ='cyan')
plt.plot(df3.loc['Experimento 1- RELU+ADAGRAD'],'o-',label ='Experimento 1- RELU+ADAGRAD',color ='purple')
plt.plot(df3.loc['Experimento 2- RELU+ADAGRAD'],'o-',label ='Experimento 2- RELU+ADAGRAD',color ='orange')
plt.plot(df3.loc['Experimento 3- RELU+ADAGRAD'],'o-',label ='Experimento 3- RELU+ADAGRAD',color ='yellow')
plt.title('Conjunto de datos 3')
plt.legend(bbox_to_anchor = (2, 1))
